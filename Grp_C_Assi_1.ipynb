# %%
# import module
import requests
from bs4 import BeautifulSoup

# %%
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
            AppleWebKit/537.36 (KHTML, like Gecko) \
            Chrome/90.0.4430.212 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
# Scrape the data
def getdata(site_url):
    res = requests.get(site_url, headers=HEADERS)
    return res.text

# %%
def gethtml(site_url):

    # pass the url
    # into getdata function
    data = getdata(site_url)
    soup = BeautifulSoup(data, 'html.parser')

    # display html code
    return (soup)

# %%
# site_url = "https://www.amazon.in/Columbia-Mens-wind-\
# resistant-Glove/dp/B0772WVHPS/?_encoding=UTF8&pd_rd\
# _w=d9RS9&pf_rd_p=3d2ae0df-d986-4d1d-8c95-aa25d2ade606&pf\
# _rd_r=7MP3ZDYBBV88PYJ7KEMJ&pd_rd_r=550bec4d-5268-41d5-\
# 87cb-8af40554a01e&pd_rd_wg=oy8v8&ref_=pd_gw_cr_cartx&th=1"

site_url= "https://www.amazon.com/Samsung-Galaxy-Unlocked-T-Mobile-International/dp/B09GPRKX24/ref=sr_1_1?keywords=moble&qid=1651568489&sr=8-1&th=1"

soup = gethtml(site_url)
#print(soup)

# %%
def getCustomerName(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_string = ""
    custumer_list = []
  
    for item in soup.find_all("span", class_="a-profile-name"):
        data_string = data_string + item.get_text()
        custumer_list.append(data_string)
        data_string = ""
    return custumer_list

# %%
custumer_res = getCustomerName(soup)
for i in custumer_res:
    print(i)
#print(custumer_res)
# Out:
# Amazon Customer
# O. Marti
# Adria Halstead-Johnson
# Kofi A.
# Babydaddy
# Daniel M.
# Bonnie
# Alfonso Vargas
# raiden

# %%
def getCustomerName(soup):
    # find the Html tag
        # with find()
    # and convert into string
    data_string = ""
    custumer_list = []
    
    for item in soup.find_all("span", class_="review-text"):
        data_string = data_string + item.get_text()
        custumer_list.append(data_string)
        data_string = ""
    return custumer_list

# %%
custumer_res = getCustomerName(soup)
for i in custumer_res:
    print(i)
#print(custumer_res)
# Out:
#   This phone was in like new and came with earbuds and a charger.  Unfortunately I could not get it to work with the T-Mobile network even after spending over 2 hours with T-Mobile support.
#
# Read more
#
#
#   Purchased this phone based on the write-up only to discover it is not compatible in the USA with AT & T. Will be returning it.
#
# Read more
#
#
#   Product arrived a couple of days early 👌. The phone is new and sturdy. Turned it on but didn't take me  through the usual setup process I am used to with other phones bought in the past. The phone came on with a foreign language which I later found out to be Thai. I couldn't default it to English without the help of a friend to do that with much challenge... reason for the 4 star. When I thought it was all said and done, the internet browser brought up the Thai language again. Realized the URL directed me to Thai site, changed that to a familiar one and it was now in English. The browser seems to remember the last URL even when deactivated and reactivated so didn't have the Thai Language problem again. The phone has password, facial and finger print security features. I opted for the fingerprint security feature (password is a required option) and found it to be work real well. It also has 2 dedicated SIM card slots and a micro SD slot unlike some that uses one of the SIM card slots optionally for the micro SD card. Plan to use the phone for my international travels so I am yet to test all the appropriate functionalities of the phone having received it only yesterday. Therefore I can't grade the battery life yet.
#
# Read more
#
#
#   Touch Screen was completely inoperable on day 1. Wouldn’t buy from the vendor ever again. Complete rip-off. STAY AWAY!!
#
# Read more
#
#
#   El audio es malísimo Cuando estás en una llamada la bocina no se escucha nada, en altavoz la otra persona no te escucha, al parecer hay una distorsión o interferencia con los altavoces y el micrófono, cuando utilazas bocinas Bluetooth el audio es mucho peor, lograr obtener un buen audio es súper difícil o imposible, no es un teléfono de buena calidad para la marca y por el precio que pagué. Estoy súper decepcionado, no lo devuelvo porque me saldría muy caro el envío desde república Dominicana. Le doy una estrella porque no hay menos.
#
# Read more
#
#
#   My only complaint was it would not work with H2O minute plans. Besides that and the fact I had to return this totally awesome phone (hassle free)because of my minute plan,it is a pretty cool phone,and the cameras,well that is why I bought it in the first place ,they all worked great. I will be looking for this model that will work with my minute plan. I liked the feel of the phone and ease of setting it up. Worth the money IF it will work with your minute plan.
#
# Read more
#
#
#   1st one was locked. Got a replacement... replacement couldn't be used away from the house, when on a call,,will lose reception often, couldn't hardly hear, speaker will be too low. Stop 🛑 I still got to see my refund in my account, Wich it's been a week already since I sent it back for a refund.
#
# Read more
#
#
#   So far this phone is doing very well. I got it for my 13 year old. It was a upgrade from his S6 phone. This phone does it all for the price. Check this one out if u need a replacement.
#
# Read more

# %%
def getCustomerName(soup):
    # find the Html tag
        # with find()
    # and convert into string
    data_string = ""
    custumer_list = []
    
    for item in soup.find_all("span", class_="a-icon-alt"):
        data_string = data_string + item.get_text()
        custumer_list.append(data_string)
        data_string = ""
    return custumer_list

# %%
custumer_res = getCustomerName(soup)
for i in custumer_res:
    print(i)
#print(custumer_res)
# Out:
# 3.9 out of 5 stars
# Previous page of related Sponsored Products
# Next page of related Sponsored Products
# 3.9 out of 5 stars
# 4.1 out of 5 stars
# 4.2 out of 5 stars
# 4.3 out of 5 stars
# 3.9 out of 5 stars
# 4.2 out of 5 stars
# Previous page
# Next page
# 3.9 out of 5 stars
# Previous page of related Sponsored Products
# Next page of related Sponsored Products
# 3.9 out of 5 stars
# 1.0 out of 5 stars
# 3.0 out of 5 stars
# 1.0 out of 5 stars
# 4.0 out of 5 stars
# 1.0 out of 5 stars
# 1.0 out of 5 stars
# 5.0 out of 5 stars
# 1.0 out of 5 stars
# 5.0 out of 5 stars

# %%
def getCustomerName(soup):
    # find the Html tag
        # with find()
    # and convert into string
    data_string = ""
    custumer_list = []
    
    for item in soup.find_all("a", class_="review-title"):
        data_string = data_string + item.get_text()
        custumer_list.append(data_string)
        data_string = ""
    return custumer_list

# %%
custumer_res = getCustomerName(soup)
for i in custumer_res:
    print(i)
#print(custumer_res)
# Out:
# Great shape but did not work on T-Mobile
#
#
# Not compatible in USA
#
#
# Luv it but...
#
#
# Piece of trash( good paper weight
#
#
# El audio es muy malo.
#
#
# Awesome phone however:(
#
#
# Returned Twice.
#
#
# Good overall phone for price
