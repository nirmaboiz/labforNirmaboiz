# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("D:\Third Year Sem 2\DSBDA\\dataset_Facebook.csv")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.isnull()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               False  False     False       False         False      False
# 1               False  False     False       False         False      False
# 2               False  False     False       False         False      False
# 3               False  False     False       False         False      False
# 4               False  False     False       False         False      False
# ..                ...    ...       ...         ...           ...        ...
# 495             False  False     False       False         False      False
# 496             False  False     False       False         False      False
# 497             False  False     False       False         False      False
# 498             False  False     False       False         False      False
# 499             False  False     False       False         False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
#  CREATE DATA SUBSETS

# %%
x = df[['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
       'Post Hour', 'Paid', 'Lifetime Post Total Reach',
       'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
       'Lifetime Post Consumers', 'Lifetime Post Consumptions',
       'Lifetime Post Impressions by people who have liked your Page',
       'Lifetime Post reach by people who like your Page',
       'Lifetime People who have liked your Page and engaged with your post','comment']]

# %%
x
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
y = df[['comment', 'like', 'share', 'Total Interactions']]

# %%
y
# Out:
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
# 499        0    91.0   28.0                 119
#
# [500 rows x 4 columns]

# %%
nx=pd.DataFrame(x)

# %%
nx
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
ny=pd.DataFrame(y)

# %%
newxy=pd.merge(nx,ny,on='comment')

# %%
#newxy=pd.concat(nx,ny)

# %%
newxy
# Out:
#        Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0                139441  Photo         2          12             4          3
# 1                139441  Photo         2          12             4          3
# 2                139441  Photo         2          12             4          3
# 3                139441  Photo         2          12             4          3
# 4                139441  Photo         2          12             4          3
# ...                 ...    ...       ...         ...           ...        ...
# 25541            113028  Photo         1           4             6         14
# 25542            111620  Photo         3           4             1         14
# 25543             92507  Photo         3           2             1         13
# 25544             86909  Photo         2           1             4         11
# 25545             85979  Photo         3           1             7         10
#
# ...

# %% [markdown]
# sorting

# %%
df.sort_values(by=['Page total likes'])
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 493             85093   Photo         3           1             1          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
df.sort_values(by=['Page total likes'],ascending=False)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.transpose()
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df.stack()
# Out:
# 0    Page total likes                                                       139441
#      Type                                                                    Photo
#      Category                                                                    2
#      Post Month                                                                 12
#      Post Weekday                                                                4
#                                                                              ...
# 499  Lifetime People who have liked your Page and engaged with your post       316
#      comment                                                                     0
#      like                                                                     91.0
#      share                                                                    28.0
#      Total Interactions                                                        119
# Length: 9494, dtype: object

# %%
df.melt()
# Out:
#                 variable   value
# 0       Page total likes  139441
# 1       Page total likes  139441
# 2       Page total likes  139441
# 3       Page total likes  139441
# 4       Page total likes  139441
# ...                  ...     ...
# 9495  Total Interactions      84
# 9496  Total Interactions      75
# 9497  Total Interactions     115
# 9498  Total Interactions     136
# 9499  Total Interactions     119
#
# [9500 rows x 2 columns]

# %%
re=df.pivot(columns=['Category','Post Month'],values ='Post Hour')

# %%
re
# Out:
# Category       2    3   1   2   1   3       1   2      ...       1   3   2  \
# Post Month    12   12  12  11  11  11  10  10  10  9   ...  4   3   3   3
# 0            3.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 1           10.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 2            NaN  3.0 NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 3           10.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 4            3.0  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# ..           ...  ...  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..
# 495          NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 496          NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 497          NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# 498          NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN NaN
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %% [markdown]
# 1

# %%
df_1=df.loc[0:50,['Type','Post Weekday','Post Hour','like', 'share']]

# %%
df_1
# Out:
#       Type  Post Weekday  Post Hour    like  share
# 0    Photo             4          3    79.0   17.0
# 1   Status             3         10   130.0   29.0
# 2    Photo             3          3    66.0   14.0
# 3    Photo             2         10  1572.0  147.0
# 4    Photo             2          3   325.0   49.0
# 5   Status             1          9   152.0   33.0
# 6    Photo             1          3   249.0   27.0
# 7    Photo             7          9   325.0   14.0
# 8   Status             7          3   161.0   31.0
# 9    Photo             6         10   113.0   26.0
# 10  Status             5         10   233.0   19.0
# 11   Photo             5         10    88.0   18.0
# 12   Photo             5         10    90.0   14.0
# 13   Photo             5          3   137.0   10.0
# 14   Photo             4          5   577.0   20.0
# 15  Status             3         10    86.0   18.0
# 16   Photo             3          3    40.0   12.0
# ...

# %% [markdown]
# 2

# %%
df_2=df.loc[0:25,['Type','Total Interactions','like', 'share']]
df_2
# Out:
#       Type  Total Interactions    like  share
# 0    Photo                 100    79.0   17.0
# 1   Status                 164   130.0   29.0
# 2    Photo                  80    66.0   14.0
# 3    Photo                1777  1572.0  147.0
# 4    Photo                 393   325.0   49.0
# 5   Status                 186   152.0   33.0
# 6    Photo                 279   249.0   27.0
# 7    Photo                 339   325.0   14.0
# 8   Status                 192   161.0   31.0
# 9    Photo                 142   113.0   26.0
# 10  Status                 252   233.0   19.0
# 11   Photo                 106    88.0   18.0
# 12   Photo                 104    90.0   14.0
# 13   Photo                 152   137.0   10.0
# 14   Photo                 599   577.0   20.0
# 15  Status                 108    86.0   18.0
# 16   Photo                  54    40.0   12.0
# 17   Photo                 713   678.0   20.0
# 18  Status                  75    54.0   17.0
# ...

# %% [markdown]
# 3

# %%
df_3 = df[df['Post Hour']>3]
df_3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 7              139441   Photo         3          12             7          9
# 9              139441   Photo         3          12             6         10
# ..                ...     ...       ...         ...           ...        ...
# 492             85979    Link         1           1             5         11
# 494             85093   Photo         3           1             7         10
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# 4

# %%
df_1.sort_values(by=['like', 'share'],ascending=False)
# Out:
#       Type  Post Weekday  Post Hour    like  share
# 3    Photo             2         10  1572.0  147.0
# 17   Photo             2         12   678.0   20.0
# 14   Photo             4          5   577.0   20.0
# 28   Photo             5          3   523.0   63.0
# 26  Status             5         11   412.0   72.0
# 4    Photo             2          3   325.0   49.0
# 7    Photo             7          9   325.0   14.0
# 6    Photo             1          3   249.0   27.0
# 10  Status             5         10   233.0   19.0
# 38  Status             7          9   227.0   31.0
# 40  Status             6         11   216.0   39.0
# 41    Link             6          3   187.0   18.0
# 46  Status             3         11   174.0   36.0
# 35   Photo             1         11   172.0   21.0
# 8   Status             7          3   161.0   31.0
# 32   Photo             3          3   155.0   47.0
# 5   Status             1          9   152.0   33.0
# ...

# %% [markdown]
# 5

# %%
df_12=pd.merge(df_1,df_2,on='Type')

# %%
df_12
# Out:
#       Type  Post Weekday  Post Hour  like_x  share_x  Total Interactions  \
# 0    Photo             4          3    79.0     17.0                 100
# 1    Photo             4          3    79.0     17.0                  80
# 2    Photo             4          3    79.0     17.0                1777
# 3    Photo             4          3    79.0     17.0                 393
# 4    Photo             4          3    79.0     17.0                 279
# ..     ...           ...        ...     ...      ...                 ...
# 641   Link             6          3   187.0     18.0                  18
# 642   Link             5          3    29.0     10.0                  18
# 643   Link             4          3    57.0     10.0                  18
# 644   Link             3          2    18.0      8.0                  18
# 645   Link             2          2    12.0      1.0                  18
#
#      like_y  share_y
# 0      79.0     17.0
# 1      66.0     14.0
# 2    1572.0    147.0
# ...

# %%
df_12.sort_values(by=['share_x'])
# Out:
#       Type  Post Weekday  Post Hour  like_x  share_x  Total Interactions  \
# 265  Photo             7         10     0.0      0.0                 599
# 264  Photo             7         10     0.0      0.0                 152
# 263  Photo             7         10     0.0      0.0                 104
# 262  Photo             7         10     0.0      0.0                 106
# 261  Photo             7         10     0.0      0.0                 142
# ..     ...           ...        ...     ...      ...                 ...
# 49   Photo             2         10  1572.0    147.0                   0
# 50   Photo             2         10  1572.0    147.0                  96
# 34   Photo             2         10  1572.0    147.0                 100
# 43   Photo             2         10  1572.0    147.0                 152
# 35   Photo             2         10  1572.0    147.0                  80
#
#      like_y  share_y
# 265   577.0     20.0
# 264   137.0     10.0
# 263    90.0     14.0
# ...

# %% [markdown]
# 6

# %%
df_1.merge(df_2, left_on='like', right_on='share',suffixes=('_left', '_right'))
# Out:
#   Type_left  Post Weekday  Post Hour  like_left  share_left Type_right  \
# 0     Photo             7         10        0.0         0.0      Photo
# 1     Photo             3         10       27.0        11.0      Photo
# 2     Photo             5         10       26.0         3.0      Photo
# 3      Link             5          3       29.0        10.0     Status
# 4      Link             3          2       18.0         8.0      Photo
# 5      Link             3          2       18.0         8.0     Status
# 6      Link             3          2       18.0         8.0     Status
# 7      Link             2          2       12.0         1.0      Photo
# 8      Link             2          2       12.0         1.0      Photo
#
#    Total Interactions  like_right  share_right
# 0                   0         0.0          0.0
# 1                 279       249.0         27.0
# 2                 142       113.0         26.0
# 3                 164       130.0         29.0
# ...

# %% [markdown]
# 7

# %%
tdf_1=df_1.transpose()
tdf_1
# Out:
#                  0       1      2       3      4       5      6      7   \
# Type          Photo  Status  Photo   Photo  Photo  Status  Photo  Photo
# Post Weekday      4       3      3       2      2       1      1      7
# Post Hour         3      10      3      10      3       9      3      9
# like           79.0   130.0   66.0  1572.0  325.0   152.0  249.0  325.0
# share          17.0    29.0   14.0   147.0   49.0    33.0   27.0   14.0
#
#                   8      9   ...     41     42    43     44    45      46  \
# Type          Status  Photo  ...   Link  Photo  Link  Photo  Link  Status
# Post Weekday       7      6  ...      6      5     5      4     4       3
# Post Hour          3     10  ...      3     10     3     11     3      11
# like           161.0  113.0  ...  187.0   26.0  29.0   47.0  57.0   174.0
# share           31.0   26.0  ...   18.0    3.0  10.0   11.0  10.0    36.0
#
#                 47     48    49     50
# Type          Link  Photo  Link  Photo
# ...

# %%
tdf_1.sort_values(by=['Type'],ascending=False,axis=1)
# Out:
#                  29      25      10      1       24      18      15      38  \
# Type          Video  Status  Status  Status  Status  Status  Status  Status
# Post Weekday      4       6       5       3       6       2       3       7
# Post Hour        11       3      10      10      10       3      10       9
# like          143.0    88.0   233.0   130.0    99.0    54.0    86.0   227.0
# share          13.0    18.0    19.0    29.0    19.0    17.0    18.0    31.0
#
#                   26      5   ...     19     20     21     50    22     41  \
# Type          Status  Status  ...  Photo  Photo  Photo  Photo  Link   Link
# Post Weekday       5       1  ...      1      1      7      1     7      6
# Post Hour         11       9  ...     11      3     10      9    10      3
# like           412.0   152.0  ...   34.0   66.0    0.0   48.0  16.0  187.0
# share           72.0    33.0  ...    8.0   12.0    0.0    9.0   2.0   18.0
#
#                 43    45    47    49
# ...

# %%
tdf_2=df_2.transpose()
tdf_2
# Out:
#                        0       1      2       3      4       5      6      7   \
# Type                Photo  Status  Photo   Photo  Photo  Status  Photo  Photo
# Total Interactions    100     164     80    1777    393     186    279    339
# like                 79.0   130.0   66.0  1572.0  325.0   152.0  249.0  325.0
# share                17.0    29.0   14.0   147.0   49.0    33.0   27.0   14.0
#
#                         8      9   ...     16     17      18     19     20  \
# Type                Status  Photo  ...  Photo  Photo  Status  Photo  Photo
# Total Interactions     192    142  ...     54    713      75     42     81
# like                 161.0  113.0  ...   40.0  678.0    54.0   34.0   66.0
# share                 31.0   26.0  ...   12.0   20.0    17.0    8.0   12.0
#
#                        21    22     23      24      25
# Type                Photo  Link  Photo  Status  Status
# Total Interactions      0    18     96     121     106
# ...

# %%
tdf_2.sort_values(by=['Type'],ascending=False,axis=1)
# Out:
#                         25      15      24      5       8       18      10  \
# Type                Status  Status  Status  Status  Status  Status  Status
# Total Interactions     106     108     121     186     192      75     252
# like                  88.0    86.0    99.0   152.0   161.0    54.0   233.0
# share                 18.0    18.0    19.0    33.0    31.0    17.0    19.0
#
#                         1      23     21  ...     12     11     9      7   \
# Type                Status  Photo  Photo  ...  Photo  Photo  Photo  Photo
# Total Interactions     164     96      0  ...    104    106    142    339
# like                 130.0   72.0    0.0  ...   90.0   88.0  113.0  325.0
# share                 29.0   24.0    0.0  ...   14.0   18.0   26.0   14.0
#
#                        6      4       3      2      13    22
# Type                Photo  Photo   Photo  Photo  Photo  Link
# Total Interactions    279    393    1777     80    152    18
# ...

# %% [markdown]
# 8

# %%
df_1.melt()
# Out:
#     variable   value
# 0       Type   Photo
# 1       Type  Status
# 2       Type   Photo
# 3       Type   Photo
# 4       Type   Photo
# ..       ...     ...
# 250    share    36.0
# 251    share     8.0
# 252    share    15.0
# 253    share     1.0
# 254    share     9.0
#
# [255 rows x 2 columns]

# %%
df_2.melt()
# Out:
#     variable   value
# 0       Type   Photo
# 1       Type  Status
# 2       Type   Photo
# 3       Type   Photo
# 4       Type   Photo
# ..       ...     ...
# 99     share     0.0
# 100    share     2.0
# 101    share    24.0
# 102    share    19.0
# 103    share    18.0
#
# [104 rows x 2 columns]

# %%
df_3.melt()
# Out:
#                 variable   value
# 0       Page total likes  139441
# 1       Page total likes  139441
# 2       Page total likes  139441
# 3       Page total likes  139441
# 4       Page total likes  139441
# ...                  ...     ...
# 6683  Total Interactions     137
# 6684  Total Interactions     176
# 6685  Total Interactions      75
# 6686  Total Interactions     136
# 6687  Total Interactions     119
#
# [6688 rows x 2 columns]

# %%
result1=df.pivot(columns=['Type','Post Weekday'],values ='Post Hour')
result1
# Out:
# Type         Photo Status Photo       Status Photo      Status Photo Status  \
# Post Weekday     4      3     3     2      1     1    7      7     6      5
# 0              3.0    NaN   NaN   NaN    NaN   NaN  NaN    NaN   NaN    NaN
# 1              NaN   10.0   NaN   NaN    NaN   NaN  NaN    NaN   NaN    NaN
# 2              NaN    NaN   3.0   NaN    NaN   NaN  NaN    NaN   NaN    NaN
# 3              NaN    NaN   NaN  10.0    NaN   NaN  NaN    NaN   NaN    NaN
# 4              NaN    NaN   NaN   3.0    NaN   NaN  NaN    NaN   NaN    NaN
# ..             ...    ...   ...   ...    ...   ...  ...    ...   ...    ...
# 495            NaN    NaN   NaN   NaN    NaN   NaN  2.0    NaN   NaN    NaN
# 496            NaN    NaN   NaN   NaN    NaN   NaN  NaN    NaN   NaN    NaN
# 497            NaN    NaN   NaN   NaN    NaN   NaN  NaN    NaN   NaN    NaN
# 498           11.0    NaN   NaN   NaN    NaN   NaN  NaN    NaN   NaN    NaN
# ...

# %%
result2=df.pivot(columns=['Type','Total Interactions'],values ='like')
result2
# Out:
# Type               Photo Status Photo                Status Photo      Status  \
# Total Interactions  100    164   80      1777   393    186   279  339    192
# 0                   79.0    NaN   NaN     NaN    NaN    NaN   NaN  NaN    NaN
# 1                    NaN  130.0   NaN     NaN    NaN    NaN   NaN  NaN    NaN
# 2                    NaN    NaN  66.0     NaN    NaN    NaN   NaN  NaN    NaN
# 3                    NaN    NaN   NaN  1572.0    NaN    NaN   NaN  NaN    NaN
# 4                    NaN    NaN   NaN     NaN  325.0    NaN   NaN  NaN    NaN
# ..                   ...    ...   ...     ...    ...    ...   ...  ...    ...
# 495                  NaN    NaN   NaN     NaN    NaN    NaN   NaN  NaN    NaN
# 496                  NaN    NaN   NaN     NaN    NaN    NaN   NaN  NaN    NaN
# 497                  NaN    NaN   NaN     NaN    NaN    NaN   NaN  NaN    NaN
# 498                  NaN    NaN   NaN     NaN    NaN    NaN   NaN  NaN    NaN
# ...

# %%
result2=df.pivot(columns=['Type','Category'],values ='Post Hour')
result2
# Out:
# Type     Photo Status Photo      Status Link Video Status Link
# Category     2      2     3    1      3    1     1      1    3   2
# 0          3.0    NaN   NaN  NaN    NaN  NaN   NaN    NaN  NaN NaN
# 1          NaN   10.0   NaN  NaN    NaN  NaN   NaN    NaN  NaN NaN
# 2          NaN    NaN   3.0  NaN    NaN  NaN   NaN    NaN  NaN NaN
# 3         10.0    NaN   NaN  NaN    NaN  NaN   NaN    NaN  NaN NaN
# 4          3.0    NaN   NaN  NaN    NaN  NaN   NaN    NaN  NaN NaN
# ..         ...    ...   ...  ...    ...  ...   ...    ...  ...  ..
# 495        NaN    NaN   2.0  NaN    NaN  NaN   NaN    NaN  NaN NaN
# 496        8.0    NaN   NaN  NaN    NaN  NaN   NaN    NaN  NaN NaN
# 497        NaN    NaN   NaN  2.0    NaN  NaN   NaN    NaN  NaN NaN
# 498        NaN    NaN  11.0  NaN    NaN  NaN   NaN    NaN  NaN NaN
# 499        4.0    NaN   NaN  NaN    NaN  NaN   NaN    NaN  NaN NaN
#
# [500 rows x 10 columns]
